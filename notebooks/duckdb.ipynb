# %%
import duckdb

# %%
con = duckdb.connect(database=':memory:',read_only=False)

# %%
query = "select * from 'customers.csv'"

# %%
result = con.execute(query).fetchdf()

# %%
result.head(2)
# Out:
#    customer_id first_name last_name                      email  \
# 0         1001       John       Doe       john.doe@example.com
# 1         1002      Emily     Smith  emily.smith@example.co.uk
#
#            created_at created_date  status country
# 0 2024-01-15 08:23:45   2024-01-15  active      US
# 1 2024-02-10 14:12:30   2024-02-10  active      UK

# %%
result.shape
# Out:
# (10, 8)

# %%
filname = "Titanic-Dataset.csv"

# %%
query = f"select * from '{filname}'"

# %%
titatic_result = con.execute(query).fetchdf()

# %%
titatic_result.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500  None        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titatic_result.shape
# Out:
# (891, 12)

# %%
titatic_result.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
query = "select * from read_json_auto('products.json')"

# %%
product_result = con.execute(query).fetchdf()

# %%
product_result.head()
# Out:
#    id        name  price     category  in_stock
# 0   1      Laptop  35000  Electronics      True
# 1   2       Phone  18000  Electronics     False
# 2   3  Desk Chair   4500    Furniture      True

# %%
result.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'email', 'created_at',
#        'created_date', 'status', 'country'],
#       dtype='object')

# %%
query = """
select
    customer_id,
    first_name,
    last_name,
    email,
    created_date,
    country,
from 'customers.csv'
where status = 'active'
  and created_date >= '2024-01-01'
  and country = 'TH'
"""

# %%
customer_result2 = con.execute(query).fetchdf()

# %%
customer_result2.head(5)
# Out:
#    customer_id first_name   last_name                           email  \
# 0         1004     Sophia      Wilson     sophia.wilson@example.co.th
# 1         1008     Amanda         Lee        amanda.lee@example.co.th
# 2         1010      Nicha  Chaiyaphum  nicha.chaiyaphum@example.co.th
#
#   created_date country
# 0   2024-04-01      TH
# 1   2024-09-02      TH
# 2   2025-02-14      TH

# %%
titatic_result.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
query = """
select
    PassengerId,
    Name,
    Age,
    Fare,
    case
        when Survived = 1 then 'Survived'
        else 'Not Survived'
    end as Survived_status
from 'Titanic-Dataset.csv'
"""

# %%
transformed_data = con.execute(query).fetchdf()

# %%
transformed_data.head(5)
# Out:
#    PassengerId                                               Name   Age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5                           Allen, Mr. William Henry  35.0
#
#       Fare Survived_status
# 0   7.2500    Not Survived
# 1  71.2833        Survived
# 2   7.9250        Survived
# 3  53.1000        Survived
# 4   8.0500    Not Survived

# %%
query = "select * from 'orders.csv'"

order_result = con.execute(query).fetchdf()

order_result.columns
# Out:
# Index(['order_id', 'customer_id', 'amount', 'order_date', 'status'], dtype='object')

# %%
query = "select * from 'new_customers.csv'"

new_customer_result = con.execute(query).fetchdf()

new_customer_result.columns
# Out:
# Index(['customer_id', 'customer_name', 'segment', 'is_active'], dtype='object')

# %%
query = """
select
  c.customer_id,
  c.customer_name,
  c.segment,
  count(o.order_id) as order_count,
  sum(o.amount) as total_amount,
  avg(o.amount) as avg_amount
from 'new_customers.csv' c
left join 'orders.csv' o
  on c.customer_id = o.customer_id
  and o.status != 'cancelled'
where c.is_active = true
group by 1,2,3
"""

# %%
customer_metric = con.execute(query).fetchdf()

# %%
customer_metric.head(5)
# Out:
#   customer_id customer_name     segment  order_count  total_amount  avg_amount
# 0        C002    Jane Smith   Corporate            2         350.0      175.00
# 1        C003     Acme Corp         SMB            1          80.0       80.00
# 2        C010     Small Biz         SMB            1          45.0       45.00
# 3        C001      John Doe    Consumer            2         195.5       97.75
# 4        C005    Global LLC  Enterprise            2         800.0      400.00

# %%
query = """
with
active_orders as (
  select
    customer_id,
    count(*) as order_count,
    sum(amount) as total_amount,
    avg(amount) as avg_amount
  from 'orders.csv'
  where order_date >= date_add(current_date(), interval '-12 month')
  group by customer_id
),
active_customers as(
  select
    customer_id,
    customer_name,
    segment
  from 'new_customers.csv'
  where is_active = true

),
final_result as(
  select
    ac.*,
    coalesce(ao.order_count, 0) as order_count,
    coalesce(ao.total_amount, 0) as total_amount,
    coalesce(ao.avg_amount, 0) as avg_amount
  from active_customers ac
  left join active_orders ao
    on ac.customer_id = ao.customer_id
)

select * from final_result
"""

# %%
result2 = con.execute(query).fetchdf()

# %%
result2.head(5)
# Out:
#   customer_id   customer_name     segment  order_count  total_amount  \
# 0        C007  Cancelled Cust    Consumer            1         100.0
# 1        C009    Future Buyer  Enterprise            1        1000.0
# 2        C010       Small Biz         SMB            1          45.0
# 3        C001        John Doe    Consumer            0           0.0
# 4        C002      Jane Smith   Corporate            0           0.0
#
#    avg_amount
# 0       100.0
# 1      1000.0
# 2        45.0
# 3         0.0
# 4         0.0

# %%
query = """
WITH enriched_orders AS (
    SELECT
        o.*,
        c.customer_name,
        c.segment
    FROM orders.csv o
    LEFT JOIN new_customers.csv c
        ON o.customer_id = c.customer_id
)
SELECT
    order_id,
    customer_id,
    customer_name,
    order_date,
    amount,

    -- 1. ลำดับของ order ของลูกค้าแต่ละคน
    ROW_NUMBER() OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as order_sequence,

    -- 2. อันดับยอดขายในเดือนนั้น
    RANK() OVER (
        PARTITION BY strftime('%Y-%m', order_date)
        ORDER BY amount DESC
    ) as monthly_sales_rank,

    -- 3. ยอดสะสมของลูกค้า
    SUM(amount) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as running_total,

    -- 4. ค่าเฉลี่ยเคลื่อนที่ 4 orders
    AVG(amount) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
        ROWS BETWEEN 3 PRECEDING AND CURRENT ROW
    ) as moving_avg_4_orders,

    -- 5. ยอด order ก่อนหน้า
    LAG(amount, 1, 0) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as previous_order,

    -- 6. ยอด order ถัดไป
    LEAD(amount, 1, 0) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as next_order,

    -- 7. ยอด order แรกของลูกค้า
    FIRST_VALUE(amount) OVER (
        PARTITION BY customer_id
        ORDER BY order_date
    ) as first_order_amount

FROM enriched_orders
ORDER BY customer_id, order_date;
"""

window_analysis = con.execute(query).fetchdf()

# %%
window_analysis.head(5)
# Out:
#   order_id customer_id customer_name order_date  amount  order_sequence  \
# 0    O1001        C001      John Doe 2024-01-15   120.5               1
# 1    O1002        C001      John Doe 2024-02-20    75.0               2
# 2    O1003        C001      John Doe 2024-03-05    50.0               3
# 3    O1004        C002    Jane Smith 2024-04-25   200.0               1
# 4    O1005        C002    Jane Smith 2024-05-01   150.0               2
#
#    monthly_sales_rank  running_total  moving_avg_4_orders  previous_order  \
# 0                   1          120.5           120.500000             0.0
# 1                   1          195.5            97.750000           120.5
# 2                   1          245.5            81.833333            75.0
# 3                   1          200.0           200.000000             0.0
# 4                   1          350.0           175.000000           200.0
#
#    next_order  first_order_amount
# 0        75.0               120.5
# 1        50.0               120.5
# 2         0.0               120.5
# 3       150.0               200.0
# 4         0.0               200.0
