# %%
from prophet import Prophet
import pandas as pd

# %%
data = {
    'ds': pd.to_datetime([
        '2023-04-01', '2023-04-02', '2023-04-03', '2023-04-04', '2023-04-05',
        '2023-04-06', '2023-04-07', '2023-04-08', '2023-04-09', '2023-04-10',
        '2023-04-11', '2023-04-12', '2023-04-13', '2023-04-14', '2023-04-15',
        '2023-04-16', '2023-04-17', '2023-04-18', '2023-04-19', '2023-04-20'
    ]),
    'y': [
        120, 90, 85, 88, 92,
        95, 125, 130, 95, 80,
        80, 250, 320, 280, 150, # ช่วงสงกรานต์ที่คุณยกตัวอย่าง
        90, 85, 88, 91, 94
    ]
}
df = pd.DataFrame(data)

# แสดงข้อมูล 5 แถวแรก
print(df.head())
# Out:
#           ds    y
# 0 2023-04-01  120
# 1 2023-04-02   90
# 2 2023-04-03   85
# 3 2023-04-04   88
# 4 2023-04-05   92

# %%
holidays = pd.DataFrame({
  'holiday': 'songkran',
  'ds': pd.to_datetime(['2023-04-13']),
  'lower_window': -2,  # ให้เริ่มมีผลกระทบ 2 วันก่อนวันจริง (คือวันที่ 11, 12)
  'upper_window': 1,   # และให้มีผลกระทบต่อไปอีก 1 วันหลังวันจริง (คือวันที่ 14)
})

print(holidays)
# Out:
#     holiday         ds  lower_window  upper_window
# 0  songkran 2023-04-13            -2             1

# %%
model = Prophet(holidays=holidays, weekly_seasonality=True, yearly_seasonality=False)

# สอน Model ด้วยข้อมูลของเรา
model.fit(df)
# Out:
# 09:48:13 - cmdstanpy - INFO - Chain [1] start processing
# 09:48:13 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=10)

# พยากรณ์
forecast = model.predict(future)

# yhat คือค่าพยากรณ์หลัก
# yhat_lower และ yhat_upper คือช่วงความไม่แน่นอน

print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 25 2023-04-26   83.633438   78.095982   89.101173
# 26 2023-04-27   85.669056   80.320848   91.330408
# 27 2023-04-28  114.160657  108.318795  119.900928
# 28 2023-04-29  120.573018  114.537559  125.780196
# 29 2023-04-30   77.619273   71.256180   83.421980

# %%
fig1 = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
date_rng = pd.date_range(start='2023-01-01', end='2024-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])

# %%
np.random.seed(42) # เพื่อให้ผลลัพธ์เหมือนกันทุกครั้ง
noise = np.random.randint(0, 15, size=(len(df)))

# %%
weekday_effect = df['date'].dt.dayofweek.apply(lambda x: 25 if x >= 5 else 0) # 5=เสาร์, 6=อาทิตย์

# %%
time_trend = np.arange(len(df)) * 0.1

# %%
df['patients'] = 80 + weekday_effect + time_trend + noise

# %%
df.set_index('date', inplace=True)

df.head()
# Out:
#             patients
# date
# 2023-01-01     111.0
# 2023-01-02      83.1
# 2023-01-03      92.2
# 2023-01-04      94.3
# 2023-01-05      90.4

# %%
df['patients'].plot(figsize=(15, 5), title='Daily ER Patient Count (Simulated Data)')
plt.xlabel('Date')
plt.ylabel('Number of Patients')
plt.show()

# %%
def create_features(df):
    # สร้าง features จาก date

    df['dayofweek'] = df.index.dayofweek # 0 = จันทร์, 6 = อาทิตย์
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['dayofyear'] = df.index.dayofyear

    # สร้าง Lag Features (ข้อมูลย้อนหลัง)
    # เราจะใช้ข้อมูล 7 วันที่แล้ว และ 14 วันที่แล้วมาช่วยทาย
    df['lag_7'] = df['patients'].shift(7)
    df['lag_14'] = df['patients'].shift(14)

    # สร้าง ค่าเฉลี่ยย้อนหลัง
    df['rolling_mean_7'] = df['patients'].shift(1).rolling(window=7).mean()

    return df

df = create_features(df)

# ข้อมูลจะมีค่าว่าง (NaN) ในช่วงแรกๆ เพราะยังไม่มีข้อมูลย้อนหลังให้คำนวณ
# เราจะลบแถวที่มีค่าว่างทิ้งไป
df.dropna(inplace=True)

df.head()
# Out:
#             patients  dayofweek  quarter  month  dayofyear  lag_7  lag_14  \
# date
# 2023-01-15     113.4          6        1      1         15  109.7   111.0
# 2023-01-16      85.5          0        1      1         16   86.8    83.1
# 2023-01-17      84.6          1        1      1         17   89.9    92.2
# 2023-01-18      88.7          2        1      1         18   83.0    94.3
# 2023-01-19      88.8          3        1      1         19   87.1    90.4
#
#             rolling_mean_7
# date
# 2023-01-15       94.857143
# 2023-01-16       95.385714
# 2023-01-17       95.200000
# 2023-01-18       94.442857
# 2023-01-19       95.257143

# %%
FEATURES = ['dayofweek', 'quarter', 'month', 'dayofyear', 'lag_7', 'lag_14', 'rolling_mean_7']
TARGET = 'patients'

# %%
X = df[FEATURES]
y = df[TARGET]

# %%
split_date = '2024-10-01'
X_train, X_test = X.loc[X.index < split_date], X.loc[X.index >= split_date]
y_train, y_test = y.loc[y.index < split_date], y.loc[y.index >= split_date]

# %%
print(f"Train set: {X_train.shape[0]} samples")
print(f"Test set: {X_test.shape[0]} samples")
# Out:
# Train set: 625 samples
# Test set: 92 samples

# %%
# Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# XGBoost
xgb_model = xgb.XGBRegressor(n_estimators=100,
                             learning_rate=0.05, # ค่อยๆ เรียนรู้ช้าๆ
                             early_stopping_rounds=10, # ถ้าผลไม่ดีขึ้น 10 รอบให้หยุด
                             random_state=42)

# %%
# XGBoost ต้องมี evaluation set เพื่อใช้ early stopping
xgb_model.fit(X_train, y_train,
              eval_set=[(X_test, y_test)],
              verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=10,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
rf_pred = rf_model.predict(X_test)
xgb_pred = xgb_model.predict(X_test)

# %%
rf_mae = mean_absolute_error(y_test, rf_pred)
xgb_mae = mean_absolute_error(y_test, xgb_pred)

# %%
print(f"\nความคลาดเคลื่อนเฉลี่ยของ Random Forest: {rf_mae:.2f} คน")
print(f"ความคลาดเคลื่อนเฉลี่ยของ XGBoost: {xgb_mae:.2f} คน")
# Out:
# ความคลาดเคลื่อนเฉลี่ยของ Random Forest: 5.54 คน
# ความคลาดเคลื่อนเฉลี่ยของ XGBoost: 6.59 คน

# %%
results = pd.DataFrame({
    'Actual': y_test,
    'Random Forest': rf_pred,
    'XGBoost': xgb_pred
})

# %%
results.plot(figsize=(15, 7), style=['-', '--', ':'],
             title='Comparison of Forecast vs Actual Data')
plt.ylabel('Number of Patients')
plt.show()

# %%
def plot_feature_importance(model, features, model_name):
    # สร้าง DataFrame ของ feature importance
    fi = pd.DataFrame(data=model.feature_importances_,
                      index=features,
                      columns=['importance'])
    fi_sorted = fi.sort_values('importance', ascending=False)

    plt.figure(figsize=(10, 6))
    sns.barplot(x=fi_sorted.index, y=fi_sorted['importance'])
    plt.title(f'Feature Importance of the {model_name} Model') # Changed title to English
    plt.xticks(rotation=45)
    plt.xlabel('Features') # Added x-axis label
    plt.show()

# %%
plot_feature_importance(xgb_model, FEATURES, 'XGBoost')

# %%
plot_feature_importance(rf_model, FEATURES, 'Random Forest')

# %%
pip install git+https://github.com/amazon-science/chronos-forecasting.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/amazon-science/chronos-forecasting.git
#   Cloning https://github.com/amazon-science/chronos-forecasting.git to /tmp/pip-req-build-d13dksxu
#   Running command git clone --filter=blob:none --quiet https://github.com/amazon-science/chronos-forecasting.git /tmp/pip-req-build-d13dksxu
#   Resolved https://github.com/amazon-science/chronos-forecasting.git to commit fcd09fe8b6bf57643bde7847bf42a6719b7ee205
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch<3,>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from chronos-forecasting==1.5.3) (2.7.1)
# Collecting accelerate<2,>=0.32
#   Downloading accelerate-1.10.1-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.9/374.9 kB 28.0 MB/s eta 0:00:00
# Collecting transformers<5,>=4.48
#   Downloading transformers-4.56.1-py3-none-any.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 39.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /home/vscode/.local/lib/python3.10/site-packages (from accelerate<2,>=0.32->chronos-forecasting==1.5.3) (23.2)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.8/485.8 kB 50.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /home/vscode/.local/lib/python3.10/site-packages (from accelerate<2,>=0.32->chronos-forecasting==1.5.3) (6.0.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /home/vscode/.local/lib/python3.10/site-packages (from accelerate<2,>=0.32->chronos-forecasting==1.5.3) (1.26.4)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.10/site-packages (from accelerate<2,>=0.32->chronos-forecasting==1.5.3) (7.0.0)
# Collecting huggingface_hub>=0.21.0
#   Downloading huggingface_hub-0.35.0-py3-none-any.whl (563 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.4/563.4 kB 36.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (1.14.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (10.3.7.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (12.6.80)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (12.6.85)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (12.6.77)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (12.6.77)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (3.1.3)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (0.6.3)
# Requirement already satisfied: networkx in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (3.4.2)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (12.6.4.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (11.7.1.2)
# Requirement already satisfied: triton==3.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (3.3.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (9.5.1.17)
# Requirement already satisfied: filelock in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (3.18.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (12.6.77)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (12.5.4.2)
# Requirement already satisfied: fsspec in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (2023.12.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (2.26.2)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (11.3.0.4)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/vscode/.local/lib/python3.10/site-packages (from torch<3,>=2.0->chronos-forecasting==1.5.3) (1.11.1.6)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.10/site-packages (from triton==3.3.1->torch<3,>=2.0->chronos-forecasting==1.5.3) (75.6.0)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5,>=4.48->chronos-forecasting==1.5.3) (2.31.0)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Downloading tokenizers-0.22.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 46.9 MB/s eta 0:00:00:00:01
# Requirement already satisfied: regex!=2019.12.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5,>=4.48->chronos-forecasting==1.5.3) (2024.11.6)
# Requirement already satisfied: tqdm>=4.27 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5,>=4.48->chronos-forecasting==1.5.3) (4.67.1)
# Collecting hf-xet<2.0.0,>=1.1.3
#   Downloading hf_xet-1.1.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 50.8 MB/s eta 0:00:00:00:01
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch<3,>=2.0->chronos-forecasting==1.5.3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jinja2->torch<3,>=2.0->chronos-forecasting==1.5.3) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5,>=4.48->chronos-forecasting==1.5.3) (2025.7.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5,>=4.48->chronos-forecasting==1.5.3) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5,>=4.48->chronos-forecasting==1.5.3) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5,>=4.48->chronos-forecasting==1.5.3) (1.26.20)
# Building wheels for collected packages: chronos-forecasting
#   Building wheel for chronos-forecasting (pyproject.toml) ... done
#   Created wheel for chronos-forecasting: filename=chronos_forecasting-1.5.3-py3-none-any.whl size=29457 sha256=1ed17963a7cb042bbb2bbd927e0f5c26133b09dc77300086832dedd8cf911cd2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1w7m2nq4/wheels/bf/c1/65/08857e57345ef1b34ba0edb4791f1b2594943e82f34e93a4ab
# Successfully built chronos-forecasting
# Installing collected packages: safetensors, hf-xet, huggingface_hub, tokenizers, transformers, accelerate, chronos-forecasting
# Successfully installed accelerate-1.10.1 chronos-forecasting-1.5.3 hf-xet-1.1.10 huggingface_hub-0.35.0 safetensors-0.6.2 tokenizers-0.22.0 transformers-4.56.1
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from chronos import ChronosPipeline
# Out:
# 2025-09-17 09:52:58.112915: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-17 09:52:58.113080: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-17 09:52:59.900106: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-17 09:53:03.079301: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-17 09:53:08.454234: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
pipeline = ChronosPipeline.from_pretrained(
  "amazon/chronos-t5-small",
  device_map="cpu",
  dtype=torch.bfloat16,
)
# Out:
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/AileenNielsen/TimeSeriesAnalysisWithPython/master/data/AirPassengers.csv")

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
context = torch.tensor(df["#Passengers"])
prediction_length = 12
forecast = pipeline.predict(context, prediction_length)

# %%
forecast_index = range(len(df), len(df) + prediction_length)
low, median, high = np.quantile(forecast[0].numpy(), [0.1, 0.5, 0.9], axis=0)

plt.figure(figsize=(8, 4))
plt.plot(df["#Passengers"], color="royalblue", label="historical data")
plt.plot(forecast_index, median, color="tomato", label="median forecast")
plt.fill_between(forecast_index, low, high, color="tomato", alpha=0.3, label="80% prediction interval")
plt.legend()
plt.grid()
plt.show()

# %%
forecast[0][:][0]
# Out:
# tensor([431.5448, 400.7202, 439.7647, 441.8197, 458.2595, 556.8983, 637.0423,
#         614.4376, 524.0187, 466.4794, 402.7751, 443.8747])

# %%
# คำนวณค่ามัธยฐานของผลการพยากรณ์ในแต่ละช่วงเวลา
median_forecast = np.median(forecast[0], axis=0)

print("ค่ามัธยฐานของผลการพยากรณ์ 12 เดือนข้างหน้า")
print(median_forecast)
# Out:
# ค่ามัธยฐานของผลการพยากรณ์ 12 เดือนข้างหน้า
# [437.70972 414.0775  449.0121  476.75424 493.19403 565.11816 641.1522
#  637.0423  534.2935  482.9192  415.10498 460.31445]
